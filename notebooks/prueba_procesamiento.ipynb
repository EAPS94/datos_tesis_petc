# %%
import sys
from pathlib import Path

# Agrega el path raíz del proyecto (donde está src/)
sys.path.append(str(Path().resolve().parent))

from src.etl.procesar_archivo import procesar_hoja

# Ruta relativa al archivo de ejemplo
archivo = "../data/raw/2015/2015_PEB_Escuelas_01.xlsx"

# Procesamos la hoja de primarias
df_primarias = procesar_hoja(filepath=archivo, hoja="primarias", anio=2015)

# Vista preliminar
print("🔎 Vista previa del DataFrame:")
print(df_primarias.head())

# Información general
print("\n📊 Info general:")
print(df_primarias.info())

# Validación: columnas esperadas
print("\n✅ Columnas:")
print(df_primarias.columns.tolist())

# Crear carpeta 'output' si no existe
Path("../output").mkdir(parents=True, exist_ok=True)

# Guardar temporalmente en /output/
df_primarias.to_csv("../output/df_primarias_2015.csv", index=False, encoding="latin1")
print("\n📁 Archivo guardado en: output/df_primarias_2015.csv")
# Out:
# 🔎 Vista previa del DataFrame:
#    ENT               NOMBRE_ESCUELA CLAVE_ESCUELA       TURNO  \
# 0    1       ANTONIO VENTURA MEDINA    01DPR0002U    COMPLETO
# 1    1               BENIGNO CHAVEZ    01DPR0003T  VESPERTINO
# 2    1             15 DE SEPTIEMBRE    01DPR0005R    MATUTINO
# 3    1             TIERRA SOLIDARIA    01DPR0006Q    MATUTINO
# 4    1  MIGUEL ANGEL BARBERENA VEGA    01DPR0007P    MATUTINO
#
#             MUNICIPIO           LOCALIDAD     TIPO_ESCUELA  \
# 0  SAN JOSÉ DE GRACIA  SAN JOSE DE GRACIA  General Pública
# 1         JESÚS MARÍA         JESUS MARIA  General Pública
# 2      AGUASCALIENTES      AGUASCALIENTES  General Pública
# 3      AGUASCALIENTES      AGUASCALIENTES  General Pública
# 4      AGUASCALIENTES      AGUASCALIENTES  General Pública
#
#           GRADO_EVALUADO GRADO_MARGINACION  ALUMNOS_PROGRAMADOS  ...  \
# 0  sexto año de primaria   No identificada                   35  ...
# 1  sexto año de primaria   Muy alta o Alta                   70  ...
# 2  sexto año de primaria   Baja o Muy baja                   70  ...
# 3  sexto año de primaria   Baja o Muy baja                   32  ...
# 4  sexto año de primaria             Media                   70  ...
#
#    PERCEPCION_BIENESTAR_NACIONAL_PCT_4  MARGINACION_PARECIDAS_ALTO  \
# 0                                 11.6                        38.4
# 1                                 11.6                       100.0
# 2                                 11.6                         0.0
# 3                                 11.6                         0.0
# 4                                 11.6                         0.0
#
#    MARGINACION_PARECIDAS_MEDIO  MARGINACION_PARECIDAS_BAJO  \
# 0                         32.6                        27.7
# 1                          0.0                         0.0
# 2                          0.0                       100.0
# 3                          0.0                       100.0
# 4                        100.0                         0.0
#
#   MARGINACION_NACIONAL_ALTO MARGINACION_NACIONAL_MEDIO  \
# 0                      39.2                       30.3
# 1                      39.2                       30.3
# 2                      39.2                       30.3
# 3                      39.2                       30.3
# 4                      39.2                       30.3
#
#   MARGINACION_NACIONAL_BAJO ANIO_EVALUACION             ARCHIVO_ORIGEN  \
# 0                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 1                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 2                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 3                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 4                      29.0            2015  2015_PEB_Escuelas_01.xlsx
#
#    NOMBRE_ENTIDAD
# 0  Aguascalientes
# 1  Aguascalientes
# 2  Aguascalientes
# 3  Aguascalientes
# 4  Aguascalientes
#
# [5 rows x 76 columns]
#
# 📊 Info general:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 685 entries, 0 to 684
# Data columns (total 76 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ENT                                   685 non-null    int64
#  1   NOMBRE_ESCUELA                        684 non-null    object
#  2   CLAVE_ESCUELA                         685 non-null    object
#  3   TURNO                                 685 non-null    object
#  4   MUNICIPIO                             685 non-null    object
#  5   LOCALIDAD                             685 non-null    object
#  6   TIPO_ESCUELA                          685 non-null    object
#  7   GRADO_EVALUADO                        685 non-null    object
#  8   GRADO_MARGINACION                     685 non-null    object
#  9   ALUMNOS_PROGRAMADOS                   685 non-null    int64
#  10  ALUMNOS_EVALUADOS_LENGUAJE            685 non-null    int64
#  11  ALUMNOS_EVALUADOS_MATEMATICAS         685 non-null    int64
#  12  PORCENTAJE_EVALUADOS_LENGUAJE         685 non-null    float64
#  13  PORCENTAJE_EVALUADOS_MATEMATICAS      685 non-null    float64
#  14  REPRESENTATIVIDAD_LENGUAJE            685 non-null    object
#  15  REPRESENTATIVIDAD_MATEMATICAS         685 non-null    object
#  16  CONFIABILIDAD_LENGUAJE                685 non-null    object
#  17  CONFIABILIDAD_MATEMATICAS             685 non-null    object
#  18  ESCUELAS_PARECIDAS                    685 non-null    object
#  19  LENGUAJE_CANTIDAD_I                   685 non-null    int64
#  20  LENGUAJE_CANTIDAD_II                  685 non-null    int64
#  21  LENGUAJE_CANTIDAD_III                 685 non-null    int64
#  22  LENGUAJE_CANTIDAD_IV                  685 non-null    int64
#  23  LENGUAJE_PCT_I                        685 non-null    float64
#  24  LENGUAJE_PCT_II                       685 non-null    float64
#  25  LENGUAJE_PCT_III                      685 non-null    float64
#  26  LENGUAJE_PCT_IV                       685 non-null    float64
#  27  LENGUAJE_PARECIDAS_PCT_I              685 non-null    float64
#  28  LENGUAJE_PARECIDAS_PCT_II             685 non-null    float64
#  29  LENGUAJE_PARECIDAS_PCT_III            685 non-null    float64
#  30  LENGUAJE_PARECIDAS_PCT_IV             685 non-null    float64
#  31  LENGUAJE_NACIONAL_PCT_I               685 non-null    float64
#  32  LENGUAJE_NACIONAL_PCT_II              685 non-null    float64
#  33  LENGUAJE_NACIONAL_PCT_III             685 non-null    float64
#  34  LENGUAJE_NACIONAL_PCT_IV              685 non-null    float64
#  35  MATEMATICAS_CANTIDAD_I                685 non-null    int64
#  36  MATEMATICAS_CANTIDAD_II               685 non-null    int64
#  37  MATEMATICAS_CANTIDAD_III              685 non-null    int64
#  38  MATEMATICAS_CANTIDAD_IV               685 non-null    int64
#  39  MATEMATICAS_PCT_I                     685 non-null    float64
#  40  MATEMATICAS_PCT_II                    685 non-null    float64
#  41  MATEMATICAS_PCT_III                   685 non-null    float64
#  42  MATEMATICAS_PCT_IV                    685 non-null    float64
#  43  MATEMATICAS_PARECIDAS_PCT_I           685 non-null    float64
#  44  MATEMATICAS_PARECIDAS_PCT_II          685 non-null    float64
#  45  MATEMATICAS_PARECIDAS_PCT_III         685 non-null    float64
#  46  MATEMATICAS_PARECIDAS_PCT_IV          685 non-null    float64
#  47  MATEMATICAS_NACIONAL_PCT_I            685 non-null    float64
#  48  MATEMATICAS_NACIONAL_PCT_II           685 non-null    float64
#  49  MATEMATICAS_NACIONAL_PCT_III          685 non-null    float64
#  50  MATEMATICAS_NACIONAL_PCT_IV           685 non-null    float64
#  51  PERCEPCION_BIENESTAR_CANTIDAD_1       685 non-null    int64
#  52  PERCEPCION_BIENESTAR_CANTIDAD_2       685 non-null    int64
#  53  PERCEPCION_BIENESTAR_CANTIDAD_3       685 non-null    int64
#  54  PERCEPCION_BIENESTAR_CANTIDAD_4       685 non-null    int64
#  55  PERCEPCION_BIENESTAR_PCT_1            685 non-null    float64
#  56  PERCEPCION_BIENESTAR_PCT_2            685 non-null    float64
#  57  PERCEPCION_BIENESTAR_PCT_3            685 non-null    float64
#  58  PERCEPCION_BIENESTAR_PCT_4            685 non-null    float64
#  59  PERCEPCION_BIENESTAR_PARECIDAS_PCT_1  685 non-null    float64
#  60  PERCEPCION_BIENESTAR_PARECIDAS_PCT_2  685 non-null    float64
#  61  PERCEPCION_BIENESTAR_PARECIDAS_PCT_3  685 non-null    float64
#  62  PERCEPCION_BIENESTAR_PARECIDAS_PCT_4  685 non-null    float64
#  63  PERCEPCION_BIENESTAR_NACIONAL_PCT_1   685 non-null    float64
#  64  PERCEPCION_BIENESTAR_NACIONAL_PCT_2   685 non-null    float64
#  65  PERCEPCION_BIENESTAR_NACIONAL_PCT_3   685 non-null    float64
#  66  PERCEPCION_BIENESTAR_NACIONAL_PCT_4   685 non-null    float64
#  67  MARGINACION_PARECIDAS_ALTO            685 non-null    float64
#  68  MARGINACION_PARECIDAS_MEDIO           685 non-null    float64
#  69  MARGINACION_PARECIDAS_BAJO            685 non-null    float64
#  70  MARGINACION_NACIONAL_ALTO             685 non-null    float64
#  71  MARGINACION_NACIONAL_MEDIO            685 non-null    float64
#  72  MARGINACION_NACIONAL_BAJO             685 non-null    float64
#  73  ANIO_EVALUACION                       685 non-null    int64
#  74  ARCHIVO_ORIGEN                        685 non-null    object
#  75  NOMBRE_ENTIDAD                        685 non-null    object
# dtypes: float64(44), int64(17), object(15)
# memory usage: 406.8+ KB
# None
#
# ✅ Columnas:
# ['ENT', 'NOMBRE_ESCUELA', 'CLAVE_ESCUELA', 'TURNO', 'MUNICIPIO', 'LOCALIDAD', 'TIPO_ESCUELA', 'GRADO_EVALUADO', 'GRADO_MARGINACION', 'ALUMNOS_PROGRAMADOS', 'ALUMNOS_EVALUADOS_LENGUAJE', 'ALUMNOS_EVALUADOS_MATEMATICAS', 'PORCENTAJE_EVALUADOS_LENGUAJE', 'PORCENTAJE_EVALUADOS_MATEMATICAS', 'REPRESENTATIVIDAD_LENGUAJE', 'REPRESENTATIVIDAD_MATEMATICAS', 'CONFIABILIDAD_LENGUAJE', 'CONFIABILIDAD_MATEMATICAS', 'ESCUELAS_PARECIDAS', 'LENGUAJE_CANTIDAD_I', 'LENGUAJE_CANTIDAD_II', 'LENGUAJE_CANTIDAD_III', 'LENGUAJE_CANTIDAD_IV', 'LENGUAJE_PCT_I', 'LENGUAJE_PCT_II', 'LENGUAJE_PCT_III', 'LENGUAJE_PCT_IV', 'LENGUAJE_PARECIDAS_PCT_I', 'LENGUAJE_PARECIDAS_PCT_II', 'LENGUAJE_PARECIDAS_PCT_III', 'LENGUAJE_PARECIDAS_PCT_IV', 'LENGUAJE_NACIONAL_PCT_I', 'LENGUAJE_NACIONAL_PCT_II', 'LENGUAJE_NACIONAL_PCT_III', 'LENGUAJE_NACIONAL_PCT_IV', 'MATEMATICAS_CANTIDAD_I', 'MATEMATICAS_CANTIDAD_II', 'MATEMATICAS_CANTIDAD_III', 'MATEMATICAS_CANTIDAD_IV', 'MATEMATICAS_PCT_I', 'MATEMATICAS_PCT_II', 'MATEMATICAS_PCT_III', 'MATEMATICAS_PCT_IV', 'MATEMATICAS_PARECIDAS_PCT_I', 'MATEMATICAS_PARECIDAS_PCT_II', 'MATEMATICAS_PARECIDAS_PCT_III', 'MATEMATICAS_PARECIDAS_PCT_IV', 'MATEMATICAS_NACIONAL_PCT_I', 'MATEMATICAS_NACIONAL_PCT_II', 'MATEMATICAS_NACIONAL_PCT_III', 'MATEMATICAS_NACIONAL_PCT_IV', 'PERCEPCION_BIENESTAR_CANTIDAD_1', 'PERCEPCION_BIENESTAR_CANTIDAD_2', 'PERCEPCION_BIENESTAR_CANTIDAD_3', 'PERCEPCION_BIENESTAR_CANTIDAD_4', 'PERCEPCION_BIENESTAR_PCT_1', 'PERCEPCION_BIENESTAR_PCT_2', 'PERCEPCION_BIENESTAR_PCT_3', 'PERCEPCION_BIENESTAR_PCT_4', 'PERCEPCION_BIENESTAR_PARECIDAS_PCT_1', 'PERCEPCION_BIENESTAR_PARECIDAS_PCT_2', 'PERCEPCION_BIENESTAR_PARECIDAS_PCT_3', 'PERCEPCION_BIENESTAR_PARECIDAS_PCT_4', 'PERCEPCION_BIENESTAR_NACIONAL_PCT_1', 'PERCEPCION_BIENESTAR_NACIONAL_PCT_2', 'PERCEPCION_BIENESTAR_NACIONAL_PCT_3', 'PERCEPCION_BIENESTAR_NACIONAL_PCT_4', 'MARGINACION_PARECIDAS_ALTO', 'MARGINACION_PARECIDAS_MEDIO', 'MARGINACION_PARECIDAS_BAJO', 'MARGINACION_NACIONAL_ALTO', 'MARGINACION_NACIONAL_MEDIO', 'MARGINACION_NACIONAL_BAJO', 'ANIO_EVALUACION', 'ARCHIVO_ORIGEN', 'NOMBRE_ENTIDAD']
#
# 📁 Archivo guardado en: output/df_primarias_2015.csv

# %%
import pandas as pd
from src.etl.columnas_estandar import columnas_estandar

# Diccionario de claves ENT a nombres de entidad
ENTIDADES = {
    1: "Aguascalientes", 2: "Baja California", 3: "Baja California Sur", 4: "Campeche",
    5: "Coahuila", 6: "Colima", 7: "Chiapas", 8: "Chihuahua", 9: "Ciudad de México",
    10: "Durango", 11: "Guanajuato", 12: "Guerrero", 13: "Hidalgo", 14: "Jalisco",
    15: "Estado de México", 16: "Michoacán", 17: "Morelos", 18: "Nayarit", 19: "Nuevo León",
    20: "Oaxaca", 21: "Puebla", 22: "Querétaro", 23: "Quintana Roo", 24: "San Luis Potosí",
    25: "Sinaloa", 26: "Sonora", 27: "Tabasco", 28: "Tamaulipas", 29: "Tlaxcala",
    30: "Veracruz", 31: "Yucatán", 32: "Zacatecas"
}
anio = "2015"

archivo = "../data/raw/2015/2015_PEB_Escuelas_01.xlsx"
df = pd.read_excel(archivo, sheet_name="primarias", header=None, skiprows=3)

# Renombra columnas
df.columns = columnas_estandar

# Agrega columnas auxiliares
df["ANIO_EVALUACION"] = anio
df["ARCHIVO_ORIGEN"] = Path(archivo).name
df["NOMBRE_ENTIDAD"] = df["ENT"].map(ENTIDADES)

print(df)
# Out:
#      ENT               NOMBRE_ESCUELA CLAVE_ESCUELA       TURNO  \
# 0      1      RODRIGO RINCON GALLARDO    01DPR0001V    MATUTINO
# 1      1       ANTONIO VENTURA MEDINA    01DPR0002U    COMPLETO
# 2      1               BENIGNO CHAVEZ    01DPR0003T  VESPERTINO
# 3      1             15 DE SEPTIEMBRE    01DPR0005R    MATUTINO
# 4      1             TIERRA SOLIDARIA    01DPR0006Q    MATUTINO
# ..   ...                          ...           ...         ...
# 681    1    COLEGIO NUEVOS HORIZONTES    01PPR0133R    MATUTINO
# 682    1  COLEGIO KAROL JOZEF WOJTYLA    01PPR0134Q    MATUTINO
# 683    1            COLEGIO MARANATHA    01PPR0138M    MATUTINO
# 684    1       INSTITUTO MENDEL, A.C.    01PPR0140A    MATUTINO
# 685    1          PRIMARIA ZAUBERLAND    01PPR0142Z    MATUTINO
#
#               MUNICIPIO           LOCALIDAD     TIPO_ESCUELA  \
# 0       RINCÓN DE ROMOS     RINCON DE ROMOS  General Pública
# 1    SAN JOSÉ DE GRACIA  SAN JOSE DE GRACIA  General Pública
# 2           JESÚS MARÍA         JESUS MARIA  General Pública
# 3        AGUASCALIENTES      AGUASCALIENTES  General Pública
# 4        AGUASCALIENTES      AGUASCALIENTES  General Pública
# ..                  ...                 ...              ...
# 681         JESÚS MARÍA            EL LLANO          Privada
# 682         JESÚS MARÍA         JESUS MARIA          Privada
# 683      AGUASCALIENTES      AGUASCALIENTES          Privada
# 684      AGUASCALIENTES      AGUASCALIENTES          Privada
# 685      AGUASCALIENTES      AGUASCALIENTES          Privada
#
#             GRADO_EVALUADO GRADO_MARGINACION  ALUMNOS_PROGRAMADOS  ...  \
# 0    sexto año de primaria             Media                   35  ...
# 1    sexto año de primaria   No identificada                   35  ...
# 2    sexto año de primaria   Muy alta o Alta                   70  ...
# 3    sexto año de primaria   Baja o Muy baja                   70  ...
# 4    sexto año de primaria   Baja o Muy baja                   32  ...
# ..                     ...               ...                  ...  ...
# 681  sexto año de primaria   Baja o Muy baja                   33  ...
# 682  sexto año de primaria   Muy alta o Alta                   22  ...
# 683  sexto año de primaria   Baja o Muy baja                    4  ...
# 684  sexto año de primaria   Baja o Muy baja                   14  ...
# 685  sexto año de primaria   No identificada                    3  ...
#
#      PERCEPCION_BIENESTAR_NACIONAL_PCT_4  MARGINACION_PARECIDAS_ALTO  \
# 0                                   11.6                         0.0
# 1                                   11.6                        38.4
# 2                                   11.6                       100.0
# 3                                   11.6                         0.0
# 4                                   11.6                         0.0
# ..                                   ...                         ...
# 681                                 11.6                         0.0
# 682                                 11.6                       100.0
# 683                                 11.6                         0.0
# 684                                 11.6                         0.0
# 685                                 11.6                         8.0
#
#      MARGINACION_PARECIDAS_MEDIO  MARGINACION_PARECIDAS_BAJO  \
# 0                          100.0                         0.0
# 1                           32.6                        27.7
# 2                            0.0                         0.0
# 3                            0.0                       100.0
# 4                            0.0                       100.0
# ..                           ...                         ...
# 681                          0.0                       100.0
# 682                          0.0                         0.0
# 683                          0.0                       100.0
# 684                          0.0                       100.0
# 685                         26.2                        63.4
#
#     MARGINACION_NACIONAL_ALTO MARGINACION_NACIONAL_MEDIO  \
# 0                        39.2                       30.3
# 1                        39.2                       30.3
# 2                        39.2                       30.3
# 3                        39.2                       30.3
# 4                        39.2                       30.3
# ..                        ...                        ...
# 681                      39.2                       30.3
# 682                      39.2                       30.3
# 683                      39.2                       30.3
# 684                      39.2                       30.3
# 685                      39.2                       30.3
#
#     MARGINACION_NACIONAL_BAJO ANIO_EVALUACION             ARCHIVO_ORIGEN  \
# 0                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 1                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 2                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 3                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 4                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# ..                        ...             ...                        ...
# 681                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 682                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 683                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 684                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 685                      29.0            2015  2015_PEB_Escuelas_01.xlsx
#
#      NOMBRE_ENTIDAD
# 0    Aguascalientes
# 1    Aguascalientes
# 2    Aguascalientes
# 3    Aguascalientes
# 4    Aguascalientes
# ..              ...
# 681  Aguascalientes
# 682  Aguascalientes
# 683  Aguascalientes
# 684  Aguascalientes
# 685  Aguascalientes
#
# [686 rows x 76 columns]

# %%
import sys
from pathlib import Path

# Agrega el path raíz del proyecto (donde está src/)
sys.path.append(str(Path().resolve().parent))

from src.etl.procesar_archivo import procesar_hoja

# Ruta relativa al archivo de ejemplo
archivo = "../data/raw/2015/2015_PEB_Escuelas_01.xlsx"

# Procesamos la hoja de primarias
df_primarias = procesar_hoja(filepath=archivo, hoja="primarias", anio=2015)
print(df_primarias)
# Out:
#      ENT               NOMBRE_ESCUELA CLAVE_ESCUELA       TURNO  \
# 0      1       ANTONIO VENTURA MEDINA    01DPR0002U    COMPLETO
# 1      1               BENIGNO CHAVEZ    01DPR0003T  VESPERTINO
# 2      1             15 DE SEPTIEMBRE    01DPR0005R    MATUTINO
# 3      1             TIERRA SOLIDARIA    01DPR0006Q    MATUTINO
# 4      1  MIGUEL ANGEL BARBERENA VEGA    01DPR0007P    MATUTINO
# ..   ...                          ...           ...         ...
# 680    1    COLEGIO NUEVOS HORIZONTES    01PPR0133R    MATUTINO
# 681    1  COLEGIO KAROL JOZEF WOJTYLA    01PPR0134Q    MATUTINO
# 682    1            COLEGIO MARANATHA    01PPR0138M    MATUTINO
# 683    1       INSTITUTO MENDEL, A.C.    01PPR0140A    MATUTINO
# 684    1          PRIMARIA ZAUBERLAND    01PPR0142Z    MATUTINO
#
#               MUNICIPIO           LOCALIDAD     TIPO_ESCUELA  \
# 0    SAN JOSÉ DE GRACIA  SAN JOSE DE GRACIA  General Pública
# 1           JESÚS MARÍA         JESUS MARIA  General Pública
# 2        AGUASCALIENTES      AGUASCALIENTES  General Pública
# 3        AGUASCALIENTES      AGUASCALIENTES  General Pública
# 4        AGUASCALIENTES      AGUASCALIENTES  General Pública
# ..                  ...                 ...              ...
# 680         JESÚS MARÍA            EL LLANO          Privada
# 681         JESÚS MARÍA         JESUS MARIA          Privada
# 682      AGUASCALIENTES      AGUASCALIENTES          Privada
# 683      AGUASCALIENTES      AGUASCALIENTES          Privada
# 684      AGUASCALIENTES      AGUASCALIENTES          Privada
#
#             GRADO_EVALUADO GRADO_MARGINACION  ALUMNOS_PROGRAMADOS  ...  \
# 0    sexto año de primaria   No identificada                   35  ...
# 1    sexto año de primaria   Muy alta o Alta                   70  ...
# 2    sexto año de primaria   Baja o Muy baja                   70  ...
# 3    sexto año de primaria   Baja o Muy baja                   32  ...
# 4    sexto año de primaria             Media                   70  ...
# ..                     ...               ...                  ...  ...
# 680  sexto año de primaria   Baja o Muy baja                   33  ...
# 681  sexto año de primaria   Muy alta o Alta                   22  ...
# 682  sexto año de primaria   Baja o Muy baja                    4  ...
# 683  sexto año de primaria   Baja o Muy baja                   14  ...
# 684  sexto año de primaria   No identificada                    3  ...
#
#      PERCEPCION_BIENESTAR_NACIONAL_PCT_4  MARGINACION_PARECIDAS_ALTO  \
# 0                                   11.6                        38.4
# 1                                   11.6                       100.0
# 2                                   11.6                         0.0
# 3                                   11.6                         0.0
# 4                                   11.6                         0.0
# ..                                   ...                         ...
# 680                                 11.6                         0.0
# 681                                 11.6                       100.0
# 682                                 11.6                         0.0
# 683                                 11.6                         0.0
# 684                                 11.6                         8.0
#
#      MARGINACION_PARECIDAS_MEDIO  MARGINACION_PARECIDAS_BAJO  \
# 0                           32.6                        27.7
# 1                            0.0                         0.0
# 2                            0.0                       100.0
# 3                            0.0                       100.0
# 4                          100.0                         0.0
# ..                           ...                         ...
# 680                          0.0                       100.0
# 681                          0.0                         0.0
# 682                          0.0                       100.0
# 683                          0.0                       100.0
# 684                         26.2                        63.4
#
#     MARGINACION_NACIONAL_ALTO MARGINACION_NACIONAL_MEDIO  \
# 0                        39.2                       30.3
# 1                        39.2                       30.3
# 2                        39.2                       30.3
# 3                        39.2                       30.3
# 4                        39.2                       30.3
# ..                        ...                        ...
# 680                      39.2                       30.3
# 681                      39.2                       30.3
# 682                      39.2                       30.3
# 683                      39.2                       30.3
# 684                      39.2                       30.3
#
#     MARGINACION_NACIONAL_BAJO ANIO_EVALUACION             ARCHIVO_ORIGEN  \
# 0                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 1                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 2                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 3                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# 4                        29.0            2015  2015_PEB_Escuelas_01.xlsx
# ..                        ...             ...                        ...
# 680                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 681                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 682                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 683                      29.0            2015  2015_PEB_Escuelas_01.xlsx
# 684                      29.0            2015  2015_PEB_Escuelas_01.xlsx
#
#      NOMBRE_ENTIDAD
# 0    Aguascalientes
# 1    Aguascalientes
# 2    Aguascalientes
# 3    Aguascalientes
# 4    Aguascalientes
# ..              ...
# 680  Aguascalientes
# 681  Aguascalientes
# 682  Aguascalientes
# 683  Aguascalientes
# 684  Aguascalientes
#
# [685 rows x 76 columns]
